// %%
/*
 * Copyright (c) Jupyter Development Team.
 * Distributed under the terms of the Modified BSD License.
 */

import * as React from 'react';

import { Widget } from '@lumino/widgets';
import { ReactWidget } from '@jupyterlab/ui-components';

function MyComponent() {
  return <div>My Widget</div>;
}

const myWidget: Widget = ReactWidget.create(<MyComponent />);
Widget.attach(myWidget, document.body);
// Out:
// Error: Line 12, Character 18
//   return <div>My Widget</div>;
// _________________^
// TS1005: ';' expected.
//
// Line 12, Character 26
//   return <div>My Widget</div>;
// _________________________^
// TS1161: Unterminated regular expression literal.
//
// Line 15, Character 58
// const myWidget: Widget = ReactWidget.create(<MyComponent />);
// _________________________________________________________^
// TS1005: '>' expected.
//
// Line 15, Character 59
// const myWidget: Widget = ReactWidget.create(<MyComponent />);
// __________________________________________________________^
// TS1161: Unterminated regular expression literal.
//
// Line 16, Character 1
// Widget.attach(myWidget, document.body);
// ^
// TS1005: ',' expected.
//
// Line 16, Character 39
// Widget.attach(myWidget, document.body);
// ______________________________________^
// TS1005: ')' expected.
//
// Line 6, Character 24
// import * as React from 'react';
// _______________________^
// TS2307: Cannot find module 'react' or its corresponding type declarations.
//
// Line 8, Character 24
// import { Widget } from '@lumino/widgets';
// _______________________^
// TS2307: Cannot find module '@lumino/widgets' or its corresponding type declarations.
//
// Line 9, Character 29
// import { ReactWidget } from '@jupyterlab/ui-components';
// ____________________________^
// TS2307: Cannot find module '@jupyterlab/ui-components' or its corresponding type declarations.
//
// Line 12, Character 11
//   return <div>My Widget</div>;
// __________^
// TS2304: Cannot find name 'div'.
//
// Line 12, Character 15
//   return <div>My Widget</div>;
// ______________^
// TS2304: Cannot find name 'My'.
//
// Line 15, Character 46
// const myWidget: Widget = ReactWidget.create(<MyComponent />);
// _____________________________________________^
// TS2749: 'MyComponent' refers to a value, but is being used as a type here. Did you mean 'typeof MyComponent'?
//
// Line 16, Character 15
// Widget.attach(myWidget, document.body);
// ______________^
// TS2448: Block-scoped variable 'myWidget' used before its declaration.
//     at execTranspile (/usr/local/lib/node_modules/itypescript/lib/kernel.js:229:23)
//     at Session.transpiler [as transpile] (/usr/local/lib/node_modules/itypescript/lib/kernel.js:288:35)
//     at Session._runNow (/usr/local/lib/node_modules/itypescript/node_modules/nel/lib/nel.js:835:39)
//     at Session._run (/usr/local/lib/node_modules/itypescript/node_modules/nel/lib/nel.js:786:14)
//     at Session.execute (/usr/local/lib/node_modules/itypescript/node_modules/nel/lib/nel.js:929:10)
//     at Kernel.execute_request (/usr/local/lib/node_modules/itypescript/node_modules/jp-kernel/lib/handlers_v5.js:116:18)
//     at Kernel.onShellMessage (/usr/local/lib/node_modules/itypescript/node_modules/jp-kernel/lib/jp-kernel.js:285:41)
//     at Socket.<anonymous> (/usr/local/lib/node_modules/itypescript/node_modules/jmp/index.js:350:17)
//     at Socket.emit (node:events:513:28)
//     at Socket._emitMessage (/usr/local/lib/node_modules/itypescript/node_modules/zeromq/lib/index.js:649:15)
